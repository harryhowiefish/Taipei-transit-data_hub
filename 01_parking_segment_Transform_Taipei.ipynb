# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("01_parking_rowdata_Taipei.csv")

# %%
df
# Out:
#      Unnamed: 0  zone1  zone  parkid          parkname   positionX  positionY  \
# 0             0    NaN   NaN      96         石牌國小地下停車場  121.513143  25.114516
# 1             1    NaN   NaN     842     弘盛開發股份有限公司停車場  121.468039  25.128225
# 2             2    NaN   NaN     494   北台國際開發有限公司石牌停車場  121.522587  25.113056
# 3             3    NaN   NaN     567   洲美快速道路高架橋下平面停車場  121.499163  25.105156
# 4             4    NaN   NaN     100         七星公園地下停車場  121.502187  25.136555
# ..          ...    ...   ...     ...               ...         ...        ...
# 449         449    NaN   NaN     326        興隆市場旁平面停車場  121.547130  24.999666
# 450         450    NaN   NaN     412          保儀路平面停車場  121.565991  24.984374
# 451         451    NaN   NaN     501        永建市場旁平面停車場  121.551507  24.988211
# 452         452    NaN   NaN     459   臺北市文山區文山行政中心停車場  121.570096  24.989567
# 453         453    NaN   NaN     934  禮頓企業有限公司文山試院站停車場  121.547469  24.986754
#
#                                               parkdesc  \
# 0    大型車:0格，小型車:461格(含身心障礙停車位10格，孕婦、育有六歲以下兒童停車位9格)，...
# 1                     大型車:0格，小型車:43格(含身心障礙停車位1格)，機車:0格
# 2    大型車:0格，小型車:29格(含身心障礙停車位1格，孕婦、育有六歲以下兒童停車位1格)，機車...
# 3                     大型車:0格，小型車:19格(含身心障礙停車位2格)，機車:0格
# 4    大型車:0格，小型車:328格(含身心障礙停車位6格，孕婦、育有六歲以下兒童停車位6格)，機...
# ..                                                 ...
# 449                   大型車:0格，小型車:35格(含身心障礙停車位1格)，機車:0格
# 450                   大型車:0格，小型車:44格(含身心障礙停車位1格)，機車:0格
# 451                  大型車:0格，小型車:18格(含身心障礙停車位1格)，機車:18格
# 452  大型車:0格，小型車:132格(含身心障礙停車位2格，孕婦、育有六歲以下兒童停車位2格)，機...
# 453                   大型車:0格，小型車:12格(含身心障礙停車位1格)，機車:0格
#
#                      parkaddress  \
# 0                  致遠二路80號地下1-3層
# 1                 中央北路4段532號地下2層
# 2                明德路208巷5號地下1-2層
# 3    洲美街249-271號間(北投垃圾焚化場對面左側橋孔)
# 4                七星街3號地下室(地下共2層)
# ..                           ...
# 449                    興隆路2段97號旁
# 450                    保儀路157號對面
# 451                     木柵路191巷內
# 452                    木柵路3段220號
# 453                  木柵路1段60號旁空地
#
#                                                payexam  transqty  \
# 0    計時：小型車30元/時，全程以半小時計費；機車：10元/時，當日最高20元(隔日另計)。月租...      48.0
# 1            計時：20元/時，停車未滿1小時以1小時計，逾1小時以上者，未滿半小時以半小時計。       0.0
# 2    一、計時：小型車40元/時，全程以半小時計費。二、計次：機車30元/次。三、月租：小型車9,...       2.0
# 3                                                計次50元       0.0
# 4    計時：小型車30元/時，大型重型機車30元/時，機車10元/時(最高日上限20元，隔日另計)...     118.0
# ..                                                 ...       ...
# 449                     計時：20元/時，全程以半小時計費。月租：4,800元/月。       0.0
# 450                     計時：20元/時，全程以半小時計費。月租：4,800元/月。      15.0
# 451                             計次：小型車50元/次，隔日另計。機車免費。       1.0
# 452  計時：日間30元/時(週一至週五7-20)，洽公民眾前30分鐘免費，非洽公民眾及週六、週日3...       0.0
# 453                 小型車：計時 200元/時，全程以半小時計;月租 全日10,000元       0.0
#
#      motorremainder heightlimit  iconState  numM  numS  availableCount  \
# 0              39.0         2.1          3   NaN   461             -99
# 1              -2.0         NaN          0   NaN    43             -99
# 2              -2.0         1.9          3   NaN    29             -99
# 3              -2.0         NaN          0   NaN    19             -99
# 4               0.0         2.6          1   NaN   328             -99
# ..              ...         ...        ...   ...   ...             ...
# 449            -2.0           0          0   NaN    35             -99
# 450            -2.0           2          1   NaN    44             -99
# 451            -2.0         NaN          3   NaN    18             -99
# 452            -2.0           2          0   NaN   132             -99
# 453            -2.0         NaN          0   NaN    12             -99
#
#                     source_time
# 0    2024-05-02 17:09:54.372458
# 1    2024-05-02 17:09:54.372458
# 2    2024-05-02 17:09:54.372458
# 3    2024-05-02 17:09:54.372458
# 4    2024-05-02 17:09:54.372458
# ..                          ...
# 449  2024-05-02 17:09:54.372458
# 450  2024-05-02 17:09:54.372458
# 451  2024-05-02 17:09:54.372458
# 452  2024-05-02 17:09:54.372458
# 453  2024-05-02 17:09:54.372458
#
# [454 rows x 18 columns]

# %%
# 無用資料
# df['numM'].unique()
# df['numS'].unique()
# df['availableCount'].unique()
# 暫時不討論機車
# df['motorremainder'].unique()

# %%
# parkid parkname parkaddress positionX	positionY	
#parkdesc	所有類型停車位數量
# transqty	汽車剩餘停車位
# payexam   收費標準
df = df.loc[:, ["parkname", "parkaddress", "positionX", "positionY", "parkdesc", "transqty", "payexam", "source_time"]]

# %%
df_renamed = df.rename(columns={'parkdesc': 'car_seg_total', 'transqty': 'car_seg_remainder', 'payexam':'cost'})
df_renamed
# Out:
#      parkid          parkname                  parkaddress   positionX  \
# 0        96         石牌國小地下停車場                致遠二路80號地下1-3層  121.513143
# 1       842     弘盛開發股份有限公司停車場               中央北路4段532號地下2層  121.468039
# 2       494   北台國際開發有限公司石牌停車場              明德路208巷5號地下1-2層  121.522587
# 3       567   洲美快速道路高架橋下平面停車場  洲美街249-271號間(北投垃圾焚化場對面左側橋孔)  121.499163
# 4       100         七星公園地下停車場              七星街3號地下室(地下共2層)  121.502187
# ..      ...               ...                          ...         ...
# 449     326        興隆市場旁平面停車場                    興隆路2段97號旁  121.547130
# 450     412          保儀路平面停車場                    保儀路157號對面  121.565991
# 451     501        永建市場旁平面停車場                     木柵路191巷內  121.551507
# 452     459   臺北市文山區文山行政中心停車場                    木柵路3段220號  121.570096
# 453     934  禮頓企業有限公司文山試院站停車場                  木柵路1段60號旁空地  121.547469
#
#      positionY                                      car_seg_total  \
# 0    25.114516  大型車:0格，小型車:461格(含身心障礙停車位10格，孕婦、育有六歲以下兒童停車位9格)，...
# 1    25.128225                   大型車:0格，小型車:43格(含身心障礙停車位1格)，機車:0格
# 2    25.113056  大型車:0格，小型車:29格(含身心障礙停車位1格，孕婦、育有六歲以下兒童停車位1格)，機車...
# 3    25.105156                   大型車:0格，小型車:19格(含身心障礙停車位2格)，機車:0格
# 4    25.136555  大型車:0格，小型車:328格(含身心障礙停車位6格，孕婦、育有六歲以下兒童停車位6格)，機...
# ..         ...                                                ...
# 449  24.999666                   大型車:0格，小型車:35格(含身心障礙停車位1格)，機車:0格
# 450  24.984374                   大型車:0格，小型車:44格(含身心障礙停車位1格)，機車:0格
# 451  24.988211                  大型車:0格，小型車:18格(含身心障礙停車位1格)，機車:18格
# 452  24.989567  大型車:0格，小型車:132格(含身心障礙停車位2格，孕婦、育有六歲以下兒童停車位2格)，機...
# 453  24.986754                   大型車:0格，小型車:12格(含身心障礙停車位1格)，機車:0格
#
#      car_seg_remainder                                               cost  \
# 0                 48.0  計時：小型車30元/時，全程以半小時計費；機車：10元/時，當日最高20元(隔日另計)。月租...
# 1                  0.0          計時：20元/時，停車未滿1小時以1小時計，逾1小時以上者，未滿半小時以半小時計。
# 2                  2.0  一、計時：小型車40元/時，全程以半小時計費。二、計次：機車30元/次。三、月租：小型車9,...
# 3                  0.0                                              計次50元
# 4                118.0  計時：小型車30元/時，大型重型機車30元/時，機車10元/時(最高日上限20元，隔日另計)...
# ..                 ...                                                ...
# 449                0.0                     計時：20元/時，全程以半小時計費。月租：4,800元/月。
# 450               15.0                     計時：20元/時，全程以半小時計費。月租：4,800元/月。
# 451                1.0                             計次：小型車50元/次，隔日另計。機車免費。
# 452                0.0  計時：日間30元/時(週一至週五7-20)，洽公民眾前30分鐘免費，非洽公民眾及週六、週日3...
# 453                0.0                 小型車：計時 200元/時，全程以半小時計;月租 全日10,000元
#
#                     source_time
# 0    2024-05-02 17:09:54.372458
# 1    2024-05-02 17:09:54.372458
# 2    2024-05-02 17:09:54.372458
# 3    2024-05-02 17:09:54.372458
# 4    2024-05-02 17:09:54.372458
# ..                          ...
# 449  2024-05-02 17:09:54.372458
# 450  2024-05-02 17:09:54.372458
# 451  2024-05-02 17:09:54.372458
# 452  2024-05-02 17:09:54.372458
# 453  2024-05-02 17:09:54.372458
#
# [454 rows x 9 columns]

# %%
df_renamed.dtypes

# %% [markdown]
# parkid                   int64 V
#
# parkname                object V
#
# parkaddress             object V
#
# positionX              float64 V
#
# positionY              float64 V
#
# park_segment_detail     object => 要取出小型車的數值
#
# car_remainder          float64 => int64
#
# cost                    object 暫時不動

# %%
# regular expresion 找到小型車後面的數值
import re
def find_num(data):
    for part in data:
        if '小型車' in part:
            # 使用正则表达式提取数值部分
            matches = re.findall(r'\d+', part)
            if matches:
                # 取第一个匹配的数值作为结果
                value = int(matches[0])
                return value
    return np.nan

# %%
df_renamed["car_seg_total"] = df_renamed["car_seg_total"].fillna("無此資料")
df_renamed["car_seg_total"] = df_renamed["car_seg_total"].str.split("，").apply(find_num)

df_renamed["car_seg_remainder"] = df_renamed["car_seg_remainder"].fillna(np.nan)
# 產出float

# %%
df_renamed

# %%
df_renamed.to_csv("01_parking_TransfromData_Taipei.csv")
