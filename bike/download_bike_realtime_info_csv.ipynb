# %%
import pandas as pd

url="https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"
df = pd.read_json(url)
df.to_csv("bile_usage_realtime.csv")

# %%
df.head()
# Out:
#          sno                     sna  tot  sbi sarea                 mday  \
# 0  500101001      YouBike2.0_捷運科技大樓站   28    2   大安區  2024-04-30 12:58:05
# 1  500101002  YouBike2.0_復興南路二段273號前   21    0   大安區  2024-04-30 12:59:14
# 2  500101003    YouBike2.0_國北教大實小東側門   16    6   大安區  2024-04-30 12:59:18
# 3  500101004       YouBike2.0_和平公園東側   11    3   大安區  2024-04-30 12:59:19
# 4  500101005    YouBike2.0_辛亥復興路口西北側   16    8   大安區  2024-04-30 12:59:19
#
#         lat        lng             ar     sareaen  \
# 0  25.02605  121.54360    復興南路二段235號前  Daan Dist.
# 1  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
# 2  25.02429  121.54124    和平東路二段96巷7號  Daan Dist.
# 3  25.02351  121.54282  和平東路二段118巷33號  Daan Dist.
# 4  25.02153  121.54299     復興南路二段368號  Daan Dist.
#
#                                                snaen  \
# 0               YouBike2.0_MRT Technology Bldg. Sta.
# 1           YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# ...
