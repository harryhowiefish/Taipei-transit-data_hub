# %%
import pandas as pd 
import os 
import re
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.font_manager import FontProperties
from sqlalchemy import create_engine, exc
from zoneinfo import ZoneInfo
import pymysql

# %%
username_sql = os.getenv("ANDY_USERNAME_SQL")
password_sql = os.getenv("ANDY_PASSWORD_SQL")
# server = "host.docker.internal:3306"  #docker用
server = "localhost:3306"
db_name = "group2_db"
with create_engine(f"mysql+pymysql://{username_sql}:{password_sql}@{server}/{db_name}",).connect() as conn:
    sql = """select * from mrt_station"""
    df_station = pd.read_sql(sql=sql,con=conn)

# %%
path = os.path.join(os.getcwd(),"data","MRT","mrt_realtime_crowded.csv")
df = pd.read_csv(path)
df
# Out:
#        mrt_station_id mrt_station_name line_type direction  cart1  cart2  \
# 0                BL01               頂埔        BL        上行      1      1
# 1                BL01               頂埔        BL        上行      1      1
# 2                BL01               頂埔        BL        上行      1      1
# 3                BL01               頂埔        BL        上行      1      1
# 4                BL01               頂埔        BL        上行      1      1
# ...               ...              ...       ...       ...    ...    ...
# 128761            R28              NaN         R        下行      1      1
# 128762            R28              NaN         R        下行      1      1
# 128763            R28              NaN         R        下行      1      1
# 128764            R28              NaN         R        下行      1      1
# 128765            R28              NaN         R        下行      1      1
#
#         cart3  cart4  cart5  cart6          update_time
# 0           1      1    1.0    1.0  2024-05-04 11:16:49
# 1           1      1    1.0    1.0  2024-05-04 11:26:27
# 2           1      1    1.0    1.0  2024-05-04 11:35:25
# 3           1      1    1.0    1.0  2024-05-04 11:37:42
# 4           1      1    1.0    1.0  2024-05-04 11:49:09
# ...       ...    ...    ...    ...                  ...
# 128761      1      1    1.0    1.0  2024-05-08 23:22:59
# 128762      1      1    1.0    1.0  2024-05-08 23:44:43
# 128763      1      1    1.0    1.0  2024-05-08 23:48:11
# 128764      1      1    1.0    1.0  2024-05-08 23:54:09
# 128765      1      1    1.0    1.0  2024-05-09 00:18:03
#
# [128766 rows x 11 columns]

# %%
df['update_time'] = pd.to_datetime(df['update_time'])

# %%
df["date"] = df["update_time"].dt.date
df["hour"] = df["update_time"].dt.hour

# %%
df['update_time_hour'] = df['update_time'].dt.floor('h')

# %%
df_station.to_csv("mrt_station.csv",index=False,encoding="utf-8-sig")

# %%
df_station.columns
# Out:
# Index(['mrt_station_id', 'line_type', 'mrt_station_name', 'station_en',
#        'station_address', 'lat', 'lon', 'city_code', 'district',
#        'bike_allow_on_holiday', 'update_time'],
#       dtype='object')

# %%
df = df.merge(df_station.loc[:,['mrt_station_id', 'mrt_station_name', 'lat', 'lon']],
         on="mrt_station_id",how="left",suffixes=["_l","_r"])

# %%
df["mrt_station_name_l"] = df["mrt_station_name_r"]
df.drop(columns=["mrt_station_name_r"],inplace=True)
df.rename(columns={"mrt_station_name_l":"mrt_station_name"},inplace=True)

# %%
df.columns
# Out:
# Index(['mrt_station_id', 'mrt_station_name', 'line_type', 'direction', 'cart1',
#        'cart2', 'cart3', 'cart4', 'cart5', 'cart6', 'update_time', 'date',
#        'hour', 'update_time_hour', 'lat', 'lon'],
#       dtype='object')

# %%
dfmelt = df.melt(id_vars=['mrt_station_id', 'mrt_station_name_l', 'line_type', 'direction', 'update_time_hour'], 
              value_vars=['cart1', 'cart2', 'cart3', 'cart4', 'cart5', 'cart6'],
              var_name="cart", 
              value_name='value')

# %%
df_groupby = pd.DataFrame(dfmelt.groupby(['mrt_station_id', 
                                          'mrt_station_name_l', 
                                          'line_type', 'direction',
                                          'update_time_hour','cart'])['value'].mean())

# %%
df_groupby.reset_index(drop=False,inplace=True)

# %%
df_groupby.to_csv("mrt_realtime_crowded_groupby.csv",index=False,encoding="utf-8-sig")

# %%
df_groupby.sort_values(by=["value"],ascending=False)
# Out:
#       mrt_station_id mrt_station_name_l line_type direction  \
# 75616            O13                台北橋         O        上行
# 10593           BL12               台北車站        BL        上行
# 10087           BL11                 西門        BL        下行
# 10088           BL11                 西門        BL        下行
# 75613            O13                台北橋         O        上行
# ...              ...                ...       ...       ...
# 45515           BR24              南港展覽館        BR        下行
# 45520           BR24              南港展覽館        BR        下行
# 45521           BR24              南港展覽館        BR        下行
# 45526           BR24              南港展覽館        BR        下行
# 45527           BR24              南港展覽館        BR        下行
#
#          update_time_hour   cart  value
# 75616 2024-05-06 18:00:00  cart5    4.0
# 10593 2024-05-07 09:00:00  cart4    4.0
# 10087 2024-05-06 18:00:00  cart2    4.0
# 10088 2024-05-06 18:00:00  cart3    4.0
# 75613 2024-05-06 18:00:00  cart2    4.0
# ...                   ...    ...    ...
# 45515 2024-05-08 22:00:00  cart6    NaN
# 45520 2024-05-08 23:00:00  cart5    NaN
# 45521 2024-05-08 23:00:00  cart6    NaN
# 45526 2024-05-09 00:00:00  cart5    NaN
# 45527 2024-05-09 00:00:00  cart6    NaN
#
# [113724 rows x 7 columns]

# %%
df.loc[df["mrt_station_name"].isna(),]
df.loc[df["mrt_station_id"]=="BL99",]
# Out:
#       mrt_station_id mrt_station_name line_type direction  cart1  cart2  \
# 21420           BL99              NaN        BL        下行      1      1
#
#        cart3  cart4  cart5  cart6         update_time        date  hour  \
# 21420      1      1    1.0    1.0 2024-05-08 09:00:38  2024-05-08     9
#
#          update_time_hour
# 21420 2024-05-08 09:00:00

# %%
df.columns
# Out:
# Index(['mrt_station_id', 'mrt_station_name', 'line_type', 'direction', 'cart1',
#        'cart2', 'cart3', 'cart4', 'cart5', 'cart6', 'update_time', 'date',
#        'hour', 'update_time_hour'],
#       dtype='object')

# %%
df.groupby([])
# Out:
#        mrt_station_id mrt_station_name line_type direction  cart1  cart2  \
# 0                BL01               頂埔        BL        上行      1      1
# 1                BL01               頂埔        BL        上行      1      1
# 2                BL01               頂埔        BL        上行      1      1
# 3                BL01               頂埔        BL        上行      1      1
# 4                BL01               頂埔        BL        上行      1      1
# ...               ...              ...       ...       ...    ...    ...
# 128761            R28              NaN         R        下行      1      1
# 128762            R28              NaN         R        下行      1      1
# 128763            R28              NaN         R        下行      1      1
# 128764            R28              NaN         R        下行      1      1
# 128765            R28              NaN         R        下行      1      1
#
#         cart3  cart4  cart5  cart6         update_time        date  hour
# 0           1      1    1.0    1.0 2024-05-04 11:16:49  2024-05-04    11
# 1           1      1    1.0    1.0 2024-05-04 11:26:27  2024-05-04    11
# 2           1      1    1.0    1.0 2024-05-04 11:35:25  2024-05-04    11
# 3           1      1    1.0    1.0 2024-05-04 11:37:42  2024-05-04    11
# 4           1      1    1.0    1.0 2024-05-04 11:49:09  2024-05-04    11
# ...       ...    ...    ...    ...                 ...         ...   ...
# 128761      1      1    1.0    1.0 2024-05-08 23:22:59  2024-05-08    23
# 128762      1      1    1.0    1.0 2024-05-08 23:44:43  2024-05-08    23
# 128763      1      1    1.0    1.0 2024-05-08 23:48:11  2024-05-08    23
# 128764      1      1    1.0    1.0 2024-05-08 23:54:09  2024-05-08    23
# 128765      1      1    1.0    1.0 2024-05-09 00:18:03  2024-05-09     0
#
# [128766 rows x 13 columns]

# %%
melted_data = df.melt(id_vars=['mrt_station_id', 'mrt_station_name', 'line_type', 'direction', 'update_time'],
                        value_vars=['cart1', 'cart2', 'cart3', 'cart4', 'cart5', 'cart6'],
                        var_name='car', value_name='congestion')
melted_data
# Out:
#        mrt_station_id mrt_station_name line_type direction  \
# 0                BL01               頂埔        BL        上行
# 1                BL01               頂埔        BL        上行
# 2                BL01               頂埔        BL        上行
# 3                BL01               頂埔        BL        上行
# 4                BL01               頂埔        BL        上行
# ...               ...              ...       ...       ...
# 772591            R28              NaN         R        下行
# 772592            R28              NaN         R        下行
# 772593            R28              NaN         R        下行
# 772594            R28              NaN         R        下行
# 772595            R28              NaN         R        下行
#
#                 update_time    car  congestion
# 0       2024-05-04 11:16:49  cart1         1.0
# 1       2024-05-04 11:26:27  cart1         1.0
# 2       2024-05-04 11:35:25  cart1         1.0
# 3       2024-05-04 11:37:42  cart1         1.0
# 4       2024-05-04 11:49:09  cart1         1.0
# ...                     ...    ...         ...
# 772591  2024-05-08 23:22:59  cart6         1.0
# 772592  2024-05-08 23:44:43  cart6         1.0
# 772593  2024-05-08 23:48:11  cart6         1.0
# 772594  2024-05-08 23:54:09  cart6         1.0
# 772595  2024-05-09 00:18:03  cart6         1.0
#
# [772596 rows x 7 columns]

# %%
plt.rc('font', family='Microsoft JhengHei')

# %%
melted_data.dropna(subset=['congestion'], inplace=True)

# Create a new figure with a larger size
plt.figure(figsize=(15, 10))
font = FontProperties(fname="NotoSansTC-Regular.otf")
# Create a boxplot
sns.boxplot(x='mrt_station_name', y='congestion', hue='direction', data=melted_data, palette='Set3')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Set titles and labels

plt.title('Congestion Levels by Station and Direction',fontproperties=font)
plt.xlabel('MRT Station',fontproperties=font)
plt.ylabel('Congestion Level',fontproperties=font)

# Show the plot
plt.show()

# %%
def count(stationname)
